# %%
from wilcoxon.sheets import *
import pandas as pd

# %%
df = getGeo("Malls Alternative")

# %%
df[["Name","Station","Label","Latitude","Longitude","Stores","Floors","Halal","Area","Services","Flow","Date"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-21161114131c> in <module>
# ----> 1 df[["Name","Station","Label","Latitude","Longitude","Stores","Floors","Halal","Area","Services","Flow","Date"]]
#
# ~/opt/anaconda3/envs/Python-R/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3459             if is_iterator(key):
#    3460                 key = list(key)
# -> 3461             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3462
#    3463         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/envs/Python-R/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
# ...

# %%
df
# Out:
#                        Name  Latitude   Longitude    Distance  Stores  Halal  \
# 0            Century Square  1.352361  103.943750  172.555603     135     96
# 1             Tampines Mall  1.352500  103.944722   66.790810     160     95
# 2          Our Tampines Hub  1.352900  103.941000  233.513463     130     95
# 3        Paya Lebar Quarter  1.317500  103.894000  124.711909     200     92
# 4                       Jem  1.333200  103.743380   85.096456     241     87
# ..                      ...       ...         ...         ...     ...    ...
# 115          Canberra Plaza  1.443257  103.830462   40.883023      70      2
# 116         Buangkok Square  1.384330  103.881620  723.994062      46      2
# 117  Katong Shopping Centre  1.303900  103.898900  541.075433     300      2
# 118                Le Quest  1.355800  103.741200  642.251208      49      1
# 119              Viva Vista  1.279700  103.786100  557.260466     106      1
#
# ...
