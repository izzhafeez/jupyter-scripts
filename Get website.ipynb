# %%
from wilcoxon import *

# %%
site = spiderman.website('https://en.wiktionary.org/wiki/dans#French')

# %%
site.getLists()

# %%
site.lists[48]
# Out:
# ['in (inside)\n1837 Louis Viardot, L’Ingénieux Hidalgo Don Quichotte de la Manchefr.Wikisource, translation of El ingenioso hidalgo Don Quijote de la Mancha by Miguel de Cervantes Saavedra, Chapter I:\nDans une bourgade de la Manche, dont je ne veux pas me rappeler le nom, vivait, il n’y a pas longtemps, un hidalgo ....\nIn a village of La Mancha, whose name I do not want to remember, lived, not long ago, an hidalgo ....\nIl habite dans le quartier le plus riche de Paris.He lives in the richest district of Paris.\n\nhttp://wiktionary.org/wiki/in',
# ...

# %%
list(enumerate(site.lists))
# Out:
# [(0,
#   ['1 English\n\n1.1 Noun\n1.2 Anagrams\n\n\n\nhttps://en.wiktionary.org/wiki/dans#English',
#    '1.1 Noun\n\nhttps://en.wiktionary.org/wiki/dans#Noun',
#    '1.2 Anagrams\n\nhttps://en.wiktionary.org/wiki/dans#Anagrams',
#    '2 Afrikaans\n\n2.1 Etymology\n2.2 Noun\n2.3 Verb\n\n\n\nhttps://en.wiktionary.org/wiki/dans#Afrikaans',
#    '2.1 Etymology\n\nhttps://en.wiktionary.org/wiki/dans#Etymology',
#    '2.2 Noun\n\nhttps://en.wiktionary.org/wiki/dans#Noun_2',
#    '2.3 Verb\n\nhttps://en.wiktionary.org/wiki/dans#Verb',
#    '3 Cornish\n\n3.1 Pronunciation\n3.2 Noun\n3.3 References\n\n\n\nhttps://en.wiktionary.org/wiki/dans#Cornish',
#    '3.1 Pronunciation\n\nhttps://en.wiktionary.org/wiki/dans#Pronunciation',
#    '3.2 Noun\n\nhttps://en.wiktionary.org/wiki/dans#Noun_3',
#    '3.3 References\n\nhttps://en.wiktionary.org/wiki/dans#References',
# ...

# %%
site = spiderman.website()
