# %%
import os
import pandas as pd

# %%
songs = pd.read_csv('Documents/Data/SONGS 2.csv')

# %%
songs[songs['CGAF'].notna()]
# Out:
#                      Song    BPM Key  AFCG    CGAF  FCGA  CAFG  AE   AF   AG  \
# 3        A Million Dreams  110.0   G   NaN     1.0   NaN   NaN NaN  NaN  NaN
# 7                   Alive  100.0   A   NaN     3.0   NaN   NaN NaN  NaN  NaN
# 10       All of the Stars   75.0   B   NaN     3.0   NaN   NaN NaN  NaN  NaN
# 15                Amnesia  102.0   D   NaN     3.0   NaN   NaN NaN  4.0  NaN
# 48          Country Roads  164.0   A   NaN     3.0   NaN   NaN NaN  NaN  NaN
# 53                 Demons   90.0  Db   NaN  1234.0   NaN   NaN NaN  NaN  NaN
# 56           Don’t Stop B  120.0   E   NaN  1234.0   NaN   NaN NaN  NaN  NaN
# 61          Edge of Glory  128.0   E   NaN    34.0   NaN   NaN NaN  NaN  NaN
# 66             Fight Song  176.0   G   1.0     3.0   NaN   NaN NaN  NaN  NaN
# 73             Girlfriend  164.0   A   NaN    13.0   NaN   NaN NaN  NaN  NaN
# 92        How Far I’ll Go   84.0   G   NaN     3.0   NaN   NaN NaN  NaN  NaN
# ...
