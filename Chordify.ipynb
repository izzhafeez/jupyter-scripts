# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
saved = requests.get('https://chordify.net/chords/elvis-presley-cant-help-falling-in-love-audio-elvispresleyvevo').text

# %%
saved
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n\t<head prefix="og: http://ogp.me/ns/website#">\n\t\t<meta charset="UTF-8" />\n\t\t<!-- TradeDoubler site verification 2549286 -->\n\t\t<!-- TradeDoubler site verification 3025000 -->\n\t\t<title>Elvis Presley - Can&#039;t Help Falling In Love (Audio) Chords - Chordify</title>\n\n\t\t<link rel="apple-touch-icon" sizes="120x120" href="//chordify.net/img/icons/apple-icon-120x120.png" />\n\t\t<link rel="apple-touch-icon" sizes="180x180" href="//chordify.net/img/icons/apple-icon-180x180.png" />\n\t\t<link rel="apple-touch-icon" sizes="60x60" href="//chordify.net/img/icons/apple-icon-60x60.png" />\n\t\t<link rel="canonical" href="https://chordify.net/chords/elvis-presley-cant-help-falling-in-love-audio-elvispresleyvevo" />\n\t\t<link rel="chrome-webstore-item" href="https://chrome.google.com/webstore/detail/ojbmddiahnkphhipnimckolcndkcgjgn" />\n\t\t<link rel="preconnect" href="//chordify.net"/>\t\t<link rel="dns-prefetch" href="//i.ytimg.com"/>\n\t\t<li
# ...
