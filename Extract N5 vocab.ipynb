# %%
f = open('Documents/n5 vocab.html').read()

# %%
import re

# %%
re.split('<tr class=.*?>',f)
# Out:
# ['<tbody>\n      <tr>\n        <th>#</th>\n        <th width="20%">Kana</th>\n        <th width="15%">Kanji</th>\n        <th width="10%">Type</th>\n        <th width="55%">Definition/s</th>\n      </tr>\n      ',
#  '\n        <td class="pos">\n          0\n        </td>\n        <td class="kanji">\n          ああ\n        </td>\n        <td class="kanji">\n          \n        </td>\n        <td>\n          int\n        </td>\n        <td class="eng">\n          Ah!, Oh!\n        </td>\n      </tr>\n      ',
#  '\n        <td class="pos">\n          1\n        </td>\n        <td class="kanji">\n          あう\n        </td>\n        <td class="kanji">\n          会う\n        </td>\n        <td>\n          u-v\n        </td>\n        <td class="eng">\n          to meet, to see\n        </td>\n      </tr>\n      ',
# ...
