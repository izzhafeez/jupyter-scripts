# %%
from wilcoxon.spiderman import *
import requests

# %%
site = website('https://en.dict.naver.com/#/search?range=all&query=%EA%B0%88%EC%95%84%EC%9E%85%EB%8B%A4')

# %%
site = requests.post('https://en.dict.naver.com/#/', {"range": "all", "query": "%EA%B0%88%EC%95%84%EC%9E%85%EB%8B%A4"})

# %%
vars(site)
# Out:
# {'_content': b'<!doctype html><html lang="ko"><head><meta charset="UTF-8"/><meta name="referrer" content="always"><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="viewport" content="width=device-width"/><style>body{margin: -10000px} #u_skip a{display:block;position:relative;margin-top:-10000px}</style><style>input[type="search"]::-webkit-search-cancel-button {display: none;}</style><script>window.appChunks={ "main":"https://ssl.pstatic.net/dicimg/alldict3/js/main.f2309804f8f1eaa8b728.js","app-arkodict-ko":"https://ssl.pstatic.net/dicimg/alldict3/js/app-arkodict-ko.775d361c737e417f5626.js","app-arkodict-ar":"https://ssl.pstatic.net/dicimg/alldict3/js/app-arkodict-ar.d83f49934c8812080eff.js","app-m.arkodict-ko":"https://ssl.pstatic.net/dicimg/alldict3/js/app-m.arkodict-ko.4ae8447bd9ed9e65e0e8.js","app-cskodict-ko":"https://ssl.pstatic.net/dicimg/alldict3/js/app-cskodict-ko.aaca966d9b92d7dab1b8.js","app-c
# ...

# %%
vars(site.raw)
# Out:
# {'headers': HTTPHeaderDict({'Last-Modified': 'Fri, 08 Apr 2022 03:42:42 GMT', 'Accept-Ranges': 'bytes', 'Cache-Control': 'no-cache, no-store, must-revalidate, max-age=0', 'Expires': 'Wed, 01 Feb 2012 00:00:00 GMT', 'Content-Encoding': 'gzip', 'Pragma': 'no-cache', 'Content-Length': '4791', 'Content-Type': 'text/html; charset=UTF-8', 'referrer-policy': 'unsafe-url', 'Server': 'nfront', 'Date': 'Tue, 12 Apr 2022 12:15:29 GMT', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding'}),
#  'status': 200,
#  'version': 11,
#  'reason': 'OK',
#  'strict': 0,
#  'decode_content': False,
#  'retries': Retry(total=0, connect=None, read=False, redirect=None, status=None),
#  'enforce_content_length': False,
#  'auto_close': True,
#  '_decoder': <urllib3.response.GzipDecoder at 0x7f9ca8403dc0>,
#  '_body': None,
#  '_fp': <http.client.HTTPResponse at 0x7f9caa19d070>,
#  '_original_response': <http.client.HTTPResponse at 0x7f9caa19d070>,
#  '_fp_bytes_read': 4791,
#  'msg': None,
# ...
