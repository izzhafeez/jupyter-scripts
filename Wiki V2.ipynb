# %%
import requests
from bs4 import BeautifulSoup
from tld import get_tld
import re
from tqdm import tqdm
import pandas as pd
import pinyin
from hanziconvert import HanziConv
from numpy import np
import chinese


def findWords(list_of_sentences,list_of_keywords):

    regex = re.compile('.*(' + '|'.join(list_of_keywords) + ').*',re.IGNORECASE)
    return list(filter(regex.match,list_of_sentences))

def findWordsStrict(list_of_sentences,list_of_keywords):

    regex = re.compile(r'.*\W(' + '|'.join(list_of_keywords) + r')\W.*',re.IGNORECASE)
    return list(filter(regex.match,list_of_sentences))

class website():
    
    def __init__(self,url):
        
        self.url = url
        self.domain = get_tld(url,as_object = True).fld
        self.site = BeautifulSoup(requests.get(url).text,'html.parser')
        self.href = [a['href'] for a in self.site(href=True)]
        
    def cleanHref(self,href):
        
        if href[0] == '#': return re.split('#[^#]*$',self.url)[0] + href
        elif href[0] == '/': return 'http://' + self.domain + href
        else: return href
        
    def getHref(self,hrefs = ''):
        
        if hrefs == '': hrefs = self.href
            
        self.selfHref = []
        self.intHref = []
        self.extHref = []

        for href in hrefs:

            try:
                if href[0] == '#': self.selfHref.append(re.split('#[^#]*$',self.url)[0]+href)
                elif href[0] == '/': self.intHref.append('http://'+self.domain+href)
                else: self.extHref.append(href)
            except: pass

        self.selfHref = list(set(self.selfHref))
        self.intHref = list(set(self.intHref))
        self.extHref = list(set(self.extHref))

    def getTables(self,header=True):
        
        tables = self.site('table')
        self.dfs = []
        
        for table in tables:
            
            try:
                
                headers = []
                for cell in table('tr')[0](['td','th']):
                    try: headers.extend([cell.getText().replace(r'\n',' ').strip()] * int(cell['colspan']))
                    except: headers.append(cell.getText().replace(r'\n',' ').strip())

                contents = []
                for row in table('tr')[1:]:
                    content = []
                    for cell in row(['td','th']):
                        try: toAdd = cell.getText() + '\n\n' + self.cleanHref(cell.find(href=True)['href'])
                        except: toAdd = cell.getText()
                        try: content.extend([toAdd] * int(cell['colspan']))
                        except: content.append(toAdd)
                    contents.append(content)

                if header == True:
                    self.dfs.append(pd.DataFrame(contents,columns=headers).applymap(lambda x: x.replace(r'\n',' ').strip()))
                    
                else:
                    data = [headers]
                    data.extend(contents)
                    self.dfs.append(pd.DataFrame(data))
                
            except: pass
    
    def combineTables(self):
        
        self.combinedTables = []
        self.combinedTablesByIndex = {}
        indices = {}
        
        for df in self.dfs:
            if ', '.join(df.columns) in indices: indices[', '.join(df.columns)].append(df)
            else: indices[', '.join(df.columns)] = [df]
                
        for index in indices:
            self.combinedTablesByIndex[index] = pd.concat(indices[index],ignore_index=True)
            self.combinedTables.append(pd.concat(indices[index],ignore_index=True))
            
            
    def getLists(self):
        
        lists = self.site(['ol','ul'])
        self.lists = []
        
        for lst in lists:
            content = []
            for li in lst('li'):
                try: content.append(li.getText() + '\n\n' + self.cleanHref(li.find(href=True)['href']))
                except: content.append(li.getText())
            self.lists.append(content)
            
    def getRelevant(self,keywords=[''],keepNewline = False,keepDuplicates = False):
        
        try:
            regex = re.compile('(' + '|'.join(keywords) + ')',re.IGNORECASE)

            hrefs = []
            self.relevantText = []
            for relevantText in self.site(string = regex):
                try:
                    hrefs.extend([href['href'] for href in relevantText.parent.parent(href=True)])
                    if keepNewline: self.relevantText.append(relevantText.parent.getText())
                    else: self.relevantText.append(re.sub('\n+',';',relevantText.parent.getText().strip('\n')))
                except: pass

            self.getHref(hrefs)

            if keepDuplicates == False:
                self.relevantText = list(set(self.relevantText))
        
        except SyntaxError: print("'keywords' must be a list.")
            
class spiderman(website):
    
    def __init__(self):
        
        self.urls = []
        self.keywords = []
        self.searchTypes = []
    
    def addUrl(self,url):
        self.urls.append(url)
        
    def addKeyword(self,keyword):
        self.keywords.append(keyword)
        
    def delUrl(self,url):
        try: self.urls.remove(url)
        except: print("Can't for some reason")
        
    def delKeyword(self,keyword):
        try: self.keywords.remove(keyword)
        except: print("Can't for some reason")
        
    def spiderman(self,keywords=[''],combine=True,limit=20):
        
        self.dfs = []
        self.lists = []
        self.texts = {}
        counter = len(self.urls)
        
        for url in tqdm(self.urls):
            
            try:
                site = website(url)
                site.getTables()
                site.getLists()
                site.getRelevant(keywords)

                if counter < limit:

                    self.urls.extend(site.intHref)
                    self.urls.extend(site.extHref)
                    self.urls = list(set(self.urls))

                self.dfs.extend(site.dfs)
                self.lists.extend(site.lists)
                
                if url not in self.texts:
                    self.texts[url] = site.relevantText
                else:
                    self.texts[url].extend(site.relevantText)

                counter += 1

            except: print(url + ' cannot be accessed.')
        
        if combine:
            self.combineTables()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f241c091a6c9> in <module>
#       6 import pandas as pd
#       7 import pinyin
# ----> 8 from hanziconvert import HanziConv
#       9 from numpy import np
#      10 import chinese
#
# ModuleNotFoundError: No module named 'hanziconvert'

# %%
spider = spiderman()
spider.addUrl('https://www.bbc.com/zhongwen/simp')

spider.spiderman(keywords=[r'[\u4e00-\u9fff]+'],limit=200)
# Out:
# 98it [03:06,  1.90s/it]

# %%
texts = []
for subline in [*spider.texts.values()]:
    texts.extend(subline)
texts = list(set(texts))

# %%
analyzer = chinese.ChineseAnalyzer()
tokens = {}
for i in tqdm(spider.texts):
    for sentence in spider.texts[i]:
        results = analyzer.parse(re.sub('[^\u4e00-\u9fff]+','',sentence))
        for token in results.tokens():
            if token in tokens: tokens[token] += 1
            else: tokens[token] = 1
# Out:
# 100%|██████████| 97/97 [00:01<00:00, 49.32it/s]

# %%
df = pd.read_csv('Documents/Data/Vocab.csv')
chinese_words = list(set(df[df['Language']=='中文']['Word']))

# %%
def tryAdd(x,y):
    if pd.notnull(x):
        return x+y
    else: return y
for token in tqdm(tokens):
    chinese_words = list(set(df[df['Language']=='中文']['Word']))
    if token not in chinese_words:
        try: usages = analyzer.parse(token)[token][0].definitions
        except: usages = np.nan
        toAdd = pd.DataFrame([['中文',HanziConv.toSimplified(token),np.nan,np.nan,np.nan,usages]],columns=['Language','Word','Chinese Translit','Transliteration','Purposes','Usages'])
        df = df.append(toAdd)
        
    df.loc[df['Word'] == HanziConv.toSimplified(token),'Importance'] = df.loc[df['Word'] == HanziConv.toSimplified(token),'Importance'].apply(lambda x: tryAdd(x,tokens[token]))
# Out:
# 100%|██████████| 12029/12029 [06:35<00:00, 30.41it/s]

# %%
import pinyin
def tryPinyin(x):
    try: return pinyin.get(x)
    except: return x

def tryTraditional(x):
    try: return HanziConv.toTraditional(x)
    except: return x
    
def tryJoin(x):
    try: 
        if type(x)==list: return ', '.join(x)
        else:
            found = re.findall("'([^']*)'",x)
            if len(found) == 0:
                return x
            else: return ', '.join(found)
    except: return x
    
def tryStrip(x):
    try: return x.strip()
    except: return x

df.loc[df['Language']=='中文','Transliteration'] = df.loc[df['Language']=='中文','Word'].apply(tryPinyin)
df.loc[df['Language']=='中文','Chinese Translit'] = df.loc[df['Language']=='中文','Word'].apply(tryTraditional)
df['Usages'] = df['Usages'].apply(tryJoin)
df = df.applymap(tryStrip)
df = df[~((df['Language']=='中文') & (pd.isnull(df['Usages'])) & (pd.isnull(df['Purposes'])))]

# %%
from hanziconvert import HanziConv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-8c16decb9c54> in <module>
# ----> 1 from hanziconvert import HanziConv
#
# ModuleNotFoundError: No module named 'hanziconvert'

# %%
import chinese
analyzer = chinese.ChineseAnalyzer()

# %%
analyzer.parse('こんなにも数多くの皆様が支えてく').tokens()
# Out:
# ['こ', 'ん', 'な', 'に', 'も', '数多', 'く', 'の', '皆', '様', 'が', '支', 'え', 'て', 'く']

# %%
site = spiderman.website('https://www.larousse.fr/dictionnaires/francais/pis/61142?q=pis#60742')

# %%
from wilcoxon import *

# %%
site.site
# Out:
# <!DOCTYPE html>
#
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="fr">
# <!-- Larousse.fr, HLVELPDW1, 27/08/2020 10:43:56 -->
# <script>
#     dataLayer = [{'lang':"fr", 'page_type':"editorial", 'page_category':"langue francaise", 'page_subcategory':"dictionnaire de francais"}];         // Problème compatiblitiy [<head></head>] & [Modify by C#]
# </script>
# <head id="Head1" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#"><meta charset="utf-8"/><meta content="Éditions Larousse" name="author"/><meta content="width=device-width, initial-scale=1" http-equiv="Content-Type" name="viewport"/><title>
# 	Définitions : pis - Dictionnaire de français Larousse
# </title>
# <!-- intégration[v.PROD]: régisPub + CNIL(v.OneTrust) -->
# <!-- ################################################ -->
# <!-- Démarrage de notification de consentement aux cookies de OneTrust -->
# <!-- ----------------------------------------------------------------- -->
# <!-- call OneTrust [v.PROD] -->
# <script charset="UTF-8" data-domain-script="9225742f-0606-4a4c-b016-9e27bd32a7a1" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript"></script>
# <!-- call OneTrust [v.RECE/DEV] -->
# <!-- <script src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript" charset="UTF-8" data-domain-script="9225742f-0606-4a4c-b016-9e27bd32a7a1-test"></script>-->
# <!-- ### dataLayer [GTM] stats Hachette #### -->
# <!-- #######################################  -->
# <script>
#         <!-- call GTM [v.PROD = GTM-TB2J4SG] / [v.RECE = GTM-W4VMQ8H] -->
#         (function(w,d,s,l,i){
#                 w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});
#                 var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';
#                 j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;
#                 f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-TB2J4SG');
#     </script>
# <!-- End Google Tag Manager -->
# <!-- JQuery core JavaScript-->
# <!-- !!! import jquery in TOP Header !!! (JS default for all Library & *.aspx) -->
# <script src="/library-web/jquery/jquery-1.9.1.min.js" type="text/javascript"></script> <!-- src="/library-web/jquery/jquery-1.9.1.js" -->
# <!-- CSS (bootstrap)-->
# <link href="/library-web/bootstrap/css/bootstrap.min.css" rel="stylesheet" type="text/css"/> <!-- href="/library-web/bootstrap/css/bootstrap.css" -->
# <!-- CSS (mdb) (!pb:navbar menuBurger & dropdown!)-->
# <link href="/library-web/mdb/css/mdb.min.css" rel="stylesheet" type="text/css"/> <!-- href="/library-web/mdb/css/mdb.css" -->
# <!-- CSS (slick)-->
# <link "="" href="/library-web/slick/slick.css" rel="stylesheet" type="text/css"/> <!-- href="./../assets/library/slick/slick.css" -->
# <link href="/library-web/slick/slick-theme.css" rel="stylesheet" type="text/css"/> <!-- href="./../assets/library/slick/slick-theme.css" -->
# <!-- CSS (font-awesome/fontello)-->
# <!--<link rel="stylesheet" type="text/css" href="/library-web/larcom/masterpage/css/font-awesome.min.css" />--> <!-- unused font awesome -->
# <link href="/library-web/larcom/masterpage/css/font-collect.css" rel="stylesheet" type="text/css"/>
# <!-- CSS (larousse-masterpage)-->
# <link href="/library-web/larcom/masterpage/css/masterpage.css" rel="stylesheet" type="text/css"/> <!-- pb: header, wrapper, footer, lar-grid-, etc...-->
# <!-- conflit CSS -->
# <style>
#         /*conflit CSS (bootstrap - MDB)*/
#         .navbar{
#             box-shadow:none;
#         }
#         /* SLICK */
#         .slick-slide {
#             outline: none !important;
#         }
#     </style>
# <link href="/dictionnaires/assets/img/favicon.ico" rel="shortcut icon"/>
# <!-- CSS (larousse-accueil)-->
# <link href="/dictionnaires/assets/css/article-olf.202003260934.css" rel="stylesheet"/> <!--href="./../assets/css/dictionnaires.css"-->
# <meta content="Définitions : pis - Dictionnaire de français Larousse" property="og:title"/>
# <meta content="Définitions : pis - Dictionnaire de français Larousse" itemprop="name"/>
# <meta content="pis - Définitions Français : Retrouvez la définition de pis... - Dictionnaire, définitions, section_expression, conjugaison, synonymes, homonymes, difficultés, citations." name="description"/>
# <meta content="pis - Définitions Français : Retrouvez la définition de pis... - Dictionnaire, définitions, section_expression, conjugaison, synonymes, homonymes, difficultés, citations." property="og:description"/>
# <meta content="pis - Définitions Français : Retrouvez la définition de pis... - Dictionnaire, définitions, section_expression, conjugaison, synonymes, homonymes, difficultés, citations." itemprop="description"/>
# <link href="https://www.larousse.fr/dictionnaires/francais/pis/61142" rel="canonical"/>
# <meta content="https://www.larousse.fr/dictionnaires/francais/pis/61142" property="og:url"/>
# <meta content="https://www.larousse.fr/dictionnaires/francais/pis/61142" itemprop="url"/>
# <meta content="dictionnaire, Larousse, français, anglais, allemand, espagnol, italien, traduction, traduire, définition, expression, conjugaison, synonyme, homonyme, citation" name="keywords"/>
# <meta content="https://www.larousse.fr/dictionnaires/assets/img/larousse.jpg" property="og:image"/>
# <meta content="https://www.larousse.fr/dictionnaires/assets/img/larousse.jpg" itemprop="image"/>
# <meta content="index,follow" name="robots"/>
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <!-- call GTM [v.PROD = GTM-TB2J4SG] / [v.RECE = GTM-W4VMQ8H] -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TB2J4SG" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="page">
# <!-- ####### HEADER ####### -->
# <div class="header">
# <!-- NAVBAR: TOP LAROUSSE (Login, Social, Culture) -->
# <!--------------------------------------------------->
# <div class="navbar navbar-inverse navbar-default lar-navbar-top visible-lg"> <!-- navbar-fixed-top  <<<>>> navbar-default -->
# <div class="container">
# <div class="navbar-collapse collapse" id="navtop">
# <ul class="lar-social nav navbar-nav navbar-right">
# <li><a href="https://www.facebook.com/larousse.fr" target="_blank"></a></li>
# <li><a href="https://twitter.com/larousse_fr" target="_blank"></a></li>
# <li><a href="https://www.instagram.com/editionslarousse/" target="_blank"></a></li>
# <li><a href="https://fr.linkedin.com/company/larousse" target="_blank"></a></li>
# </ul>
# <ul class="lar-login nav navbar-nav navbar-right">
# <li><a href="/mon-compte/identifier">Connexion/Inscription</a></li>
# <li><a href="https://www.editions-larousse.fr/newsletter">Newsletter</a></li>
# </ul>
# </div>
# </div>
# </div>
# <!-- NAVBAR: SEARCH (Labelle, saisie Recherche -->
# <!----------------------------------------------->
# <div class="lar-searchbar visible-lg">
# <a class="bt-home" href="/">LAROUSSE</a>
# <div class="zone-search">
# <input class="lar-searchtxt" onkeydown="inputKeydownHeader(false,'\\dictionnaires\\francais\\')" placeholder="Rechercher dans le dictionnaire..." type="search"/>
# <button class="lar-searchbt" onclick="onSearchHeader(false,'\\dictionnaires\\francais\\');"></button>
# </div>
# </div>
# <!-- NAVBAR: MENU (nav module: encyclo, dicos, cuisine, etc...) -->
# <!---------------------------------------------------------------->
# <div class="navbar navbar-default lar-navbar-menu">
# <div class="container">
# <div class="navbar-header">
# <button class="navbar-toggle" data-target="#navmenu" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <div class="lar-searchbar search-toggle hidden-lg">
# <div><a class="bt-home" href="/">LAROUSSE</a></div>
# <span><button class="lar-switchbt lar-openbt" onclick="openSearch()"></button></span>
# <span><button class="lar-switchbt lar-closebt" onclick="closeSearch()"></button></span>
# <div class="switch-search">
# <input class="lar-searchtxt" onkeydown="inputKeydownHeader(true,'\\dictionnaires\\francais\\')" placeholder="Rechercher dans le dictionnaire..." type="search"/>
# <button class="lar-searchbt" onclick="onSearchHeader(true,'\\dictionnaires\\francais\\');"></button>
# </div>
# </div>
# </div>
# <div class="navbar-collapse collapse" id="navmenu">
# <ul class="lar-menu nav navbar-nav navbar-left">
# <li id="olf"><a href="/dictionnaires/francais"><span class="icon-menu dropdown-submenu hidden-lg"></span>LANGUE FRANÇAISE</a></li>
# <li id="bil"><a href="/dictionnaires/bilingues"><span class="icon-menu hidden-lg"></span>DICTIONNAIRES BILINGUES</a></li>
# <li id="conj"><a href="/conjugaison"><span class="icon-menu hidden-lg"></span>CONJUGATEUR</a></li>
# <li id="encyclo"><a href="/encyclopedie"><span class="icon-menu hidden-lg"></span>ENCYCLOPÉDIE</a></li>
# <li id="cook"><a href="https://cuisine.larousse.fr"><span class="icon-menu hidden-lg"></span>CUISINE</a></li>
# <li id="forum"><a href="/forums"><span class="icon-menu hidden-lg"></span>FORUM</a></li>
# <li id="jeux"><a href="https://jeux.larousse.fr"><span class="icon-menu hidden-lg"></span>JEUX</a></li>
# <li id="archive"><a href="/archives"><span class="icon-menu hidden-lg"></span>ARCHIVES</a></li>
# <li id="books"><a href="https://www.editions-larousse.fr"><span class="icon-menu hidden-lg"></span>LIVRES</a></li>
# </ul>
# <ul class="lar-login hidden-lg">
# <li style="width:100%">
# <a href="https://www.larousse.fr/mon-compte/identifier">Connexion/Inscription</a>
# <a href="https://www.editions-larousse.fr/lettre-dinformation">Newsletter</a>
# </li>
# </ul>
# <ul class="lar-social hidden-lg">
# <li style="width:100%">
# <span>Suivez nous:</span>
# <a href="https://www.facebook.com/larousse.fr"></a>
# <a href="https://twitter.com/larousse_fr"></a>
# <a href="https://www.instagram.com/editionslarousse/"></a>
# <a href="https://fr.linkedin.com/company/larousse"></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- BANIERE(730 x 90) PUB TOP -->
# <div class="pub-top oast">
# </div>
# <!--FIL ARIANE -->
# <div class="breadcrumb">
# <div><a href="https://www.larousse.fr">Accueil</a>  &gt; <a href="/dictionnaires/francais"><b>langue française</b></a> &gt; <a href="/dictionnaires/francais-monolingue"><b>dictionnaire</b></a> &gt; <b>pis</b></div>
# </div>
# <!-- ####### HEADER ####### -->
# <!-- ##################### -->
# <!-- ## WRAPPER-CONTENT ## -->
# <!-- ##################### -->
# <div class="wrapper">
# <div class="row">
# <div class="col-md-8">
# <!-- PANEL NAV SECTION-->
# <div class="header-article">
# <header class="with-section"><h2 class="AdresseDefinition"><span class="linkaudio fontello" onclick="onSpeaker('40518fra2')"></span><audio id="40518fra2" src="/dictionnaires-prononciation/francais/tts/40518fra2" type="audio/mp3"></audio>pis</h2><p class="CatgramDefinition">nom masculin</p><p class="OrigineDefinition">(latin <i>pectus,</i> poitrine)</p>
# <nav class="section"><ul><li class="sel"><a href="/dictionnaires/francais/pis/61142#definition">Définitions</a></li><li><a href="/dictionnaires/francais/pis/61142#homonyme">Homonymes</a></li></ul></nav></header>
# </div>
# <!-- PANEL ARTICLE [DEFINITION]-->
# <div id="definition">
# <article class="BlocDefinition content" role="article"><span class="icon-section fontello"></span>
# <h1 class="TitrePage">Définitions<span class="ComplementTitre"> de pis</span></h1><br/>
# <ul class="Definitions">
# <li class="DivisionDefinition">Mamelle de certaines femelles laitières : jument, vache, chèvre, brebis.</li>
# <li class="DivisionDefinition">Partie inférieure des parois thoracique et abdominale des bovins de boucherie, de la pointe du sternum à la cuisse.</li>
# </ul>
# </article>
# </div>
# <!-- BANIERE(730 x 90) PUB MIDDLE1 -->
# <div class="pub-gtm gtm_olf1">
# </div>
# </div>
# <div class="col-md-4">
# <aside class="zone-listresult">
# <div class="banner-title">
# <hr class="line-left"/>
# <span class="homebox-title">VOUS CHERCHEZ PEUT-ÊTRE</span>
# <hr class="line-right"/>
# </div>
# <div class="hb-listresult">
# <nav class="search" role="contentinfo"><h2>Recherche <b>pis</b></h2><p class="count">8 résultats générés en 0ms</p><div class="wrapper-search"><article class="sel"><h3><a href="/dictionnaires/francais/pis/61142?q=pis#60742">pis n.m. </a></h3><p class="def">Mamelle de certaines femelles laitières : jument, vache, chèvre, brebis.</p></article><section><article><h3><a href="/dictionnaires/francais/pis/61144?q=pis#60744">pis n.m. </a></h3><p class="def">Au pis, dans l'éventualité la plus mauvaise.</p></article><article class="sous-article"><h3><a href="/dictionnaires/francais/pis/61144/locution?q=pis#164397">Au pis</a></h3></article><article class="sous-article"><h3><a href="/dictionnaires/francais/pis/61144/locution?q=pis#164398">De mal en pis</a></h3></article><article class="sous-article"><h3><a href="/dictionnaires/francais/pis/61144/locution?q=pis#164399">Dire pis que pendre de quelqu'un</a></h3></article></section><article><h3><a href="/dictionnaires/francais/pis/61143?q=pis#60743">pis adv. et adj. </a></h3><p class="def">Synonyme littéraire de pire.</p></article><article><h3><a href="/dictionnaires/francais/pis-aller/61145?q=pis#60745">pis-aller n.m. inv. </a></h3><p class="def">Ce à quoi l'on se résout, faute de mieux.</p></article><div class="banner-title itemHidden"><hr class="line-left"/><span class="homebox-title">autres résultats</span><hr class="line-right"/></div><article class="itemHidden"><h3><a href="/dictionnaires/francais/tant/76610/locution?q=pis#16001962">Tant pis</a></h3></article></div></nav>
# <div class="btPlus" id="cphContent_LarousseRWDMaster_cphContent_DictionnairesMasterPage_btExpand" onclick="onExpandResult()">Voir<span class="iconPlus">plus</span></div>
# </div>
# </aside>
# <div class="pub-pave oasm">
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <!-- PANEL ARTICLE [EXPRESSION]-->
# <div id="locution">
# </div>
# <div id="andrea_media1"></div>
# <!-- PANEL ARTICLE [SYNONIME]-->
# <div id="synonyme">
# </div>
# <!-- PANEL ARTICLE [HOMONYME]-->
# <div id="homonyme">
# <article class="Blochomonymes content" role="article"><span class="icon-section fontello"></span>
# <h1 class="TitrePage">Homonymes<span class="ComplementTitre"> de pis</span></h1><br/>
# <ul class="HomonymeDirects">
# <li class="Homonyme"><span class="Renvois"><a class="lienarticle" href="/dictionnaires/francais/pi/60674"><b>pi</b></a></span> <span class="CatGramHomonyme">nom masculin invariable</span></li>
# <li class="Homonyme"><b>pie</b> <span class="CatGramHomonyme">adjectif invariable</span></li>
# <li class="Homonyme"><b>pie</b> <span class="CatGramHomonyme">nom féminin</span></li>
# <li class="Homonyme"><b>pis</b> <span class="CatGramHomonyme">adverbe</span></li>
# </ul>
# </article>
# </div>
# <!-- BANIERE(730 x 90) PUB MIDDLE1 -->
# <div class="pub-gtm gtm_olf2">
# </div>
# <!-- PANEL ARTICLE [DIFFICULTE]-->
# <div id="difficulte">
# </div>
# <!-- PANEL ARTICLE [CITATION]-->
# <div id="citation">
# </div>
# <div id="taboola-below-article-thumbnails"></div>
# <!-- PANEL MOTS PROCHES-->
# <section class="words-nearby"><h2>Mots proches</h2><div class="slider-nearWords slider"><div class="item-word sel">pis<div class="separator">-</div></div><div class="item-word"><a href="/dictionnaires/francais/pis/61144">pis</a><div class="separator">-</div></div><div class="item-word"><a href="/dictionnaires/francais/pis/61143">pis</a><div class="separator">-</div></div><div class="item-word"><a href="/dictionnaires/francais/pis-aller/61145">pis-aller</a><div class="separator">-</div></div><div class="item-word"><a href="/dictionnaires/francais/pisan/61146">pisan</a><div class="separator">-</div></div><div class="item-word"><a href="/dictionnaires/francais/pisaure/61147">pisaure</a><div class="separator">-</div></div><div class="item-word"><a href="/dictionnaires/francais/piroplasmose/61137">piroplasmose</a><div class="separator">-</div></div><div class="item-word"><a href="/dictionnaires/francais/pirouette/61138">pirouette</a><div class="separator">-</div></div><div class="item-word"><a href="/dictionnaires/francais/pirouettement/61140">pirouettement</a><div class="separator">-</div></div><div class="item-word"><a href="/dictionnaires/francais/pirouetter/61141">pirouetter</a><div class="separator">-</div></div><div class="item-word"><a href="/dictionnaires/francais/pirouettes/61139">pirouettes</a><div class="separator">-</div></div></div></section>
# <!-- PANEL LINK-SOE -->
# <div class="panel-linkseo">
# <!-- TITLE -->
# <!-- TITLE -->
# <div class="banner-title">
# <hr class="line-left"/>
# <span class="fontello"></span>
# <hr class="line-right"/>
# <p class="panel-title"></p>
# </div>
# <!-- HOMEBOX LINK-SEO -->
# <div class="BlocLinkSEO">
# <h1>À DÉCOUVRIR DANS L'ENCYCLOPÉDIE</h1>
# <ul>
# <li><a href="/encyclopedie/medical/artefact/11349"><span class="itemtop"><b>artefact</b><b>.</b> <small>[MÉDECINE]</small></span></a></li>
# <li><a href="/encyclopedie/divers/bande_dessin%E9e/185578"><span class="itemtop"><b>bande dessinée.</b></span></a></li>
# <li><a href="/encyclopedie/divers/Barbares/107502"><span class="itemtop"><b>Barbares</b><b>.</b></span></a></li>
# <li><a href="/encyclopedie/divers/le_Consulat/114517"><span class="itemtop"><b>Consulat</b> (le).</span></a></li>
# <li><a href="/encyclopedie/personnage/Charles_Dickens/116438"><span class="itemtop"><b>Dickens</b><b>.</b> Charles <b>Dickens</b><b>.</b></span></a></li>
# <li><a href="/encyclopedie/autre-region/Gaule/120945"><span class="itemtop"><b>Gaule</b><b>.</b></span></a></li>
# <li><a href="/encyclopedie/divers/Girondins/121515"><span class="itemtop"><b>Girondins</b><b>.</b></span></a></li>
# <li><a href="/encyclopedie/vie-sauvage/hermine/184565"><span class="itemtop"><b>hermine</b><b>.</b> <small>[FAUNE]</small></span></a></li>
# <li><a href="/encyclopedie/divers/humanisme/58956"><span class="itemtop"><b>humanisme.</b></span></a></li>
# <li><a href="/encyclopedie/divers/l%E9gende/65391"><span class="itemtop"><b>légende.</b></span></a></li>
# <li><a href="/encyclopedie/personnage/Fernand_de_Magellan/131060"><span class="itemtop"><b>Magellan</b><b>.</b> Fernand de <b>Magellan</b><b>.</b></span></a></li>
# <li><a href="/encyclopedie/personnage/Pierre_Carlet_de_Chamblain_de_Marivaux/131950"><span class="itemtop"><b>Marivaux</b><b>.</b> Pierre Carlet de Chamblain de <b>Marivaux</b><b>.</b></span></a></li>
# <li><a href="/encyclopedie/personnage/Alfred_de_Musset/134495"><span class="itemtop"><b>Musset</b><b>.</b> Alfred de <b>Musset</b><b>.</b></span></a></li>
# <li><a href="/encyclopedie/vie-sauvage/phoque/178176"><span class="itemtop"><b>phoque</b><b>.</b> <small>[FAUNE]</small></span></a></li>
# <li><a href="/encyclopedie/divers/pros%E9lytisme/83691"><span class="itemtop"><b>prosélytisme.</b></span></a></li>
# <li><a href="/encyclopedie/personnage/Aurore_Dupin_baronne_Dudevant_dite_George_Sand/143001"><span class="itemtop"><b>Sand</b><b>.</b> George <b>Sand</b><b>.</b></span></a></li>
# </ul>
# </div>
# </div>
# <!-- PANEL FORUMS -->
# </div>
# <div class="col-md-4">
# <!-- HOMEBOX COURS-GUIDE -->
# <div class="zone-tools">
# <div class="banner-title">
# <hr class="line-left"/>
# <span class="homebox-title font-montserra">OUTILS</span>
# <hr class="line-right"/>
# </div>
# <div class="box-access">
# <div id="cphContent_LarousseRWDMaster_cphContent_DictionnairesMasterPage_ctl01_itemConj">
# <a class="go-line" href="https://www.larousse.fr/conjugaison">
# <div class="icon"></div>
# <div class="name">CONJUGATEUR</div>
# <div class="arrow"></div>
# </a>
# <hr/>
# </div>
# <div id="cphContent_LarousseRWDMaster_cphContent_DictionnairesMasterPage_ctl01_itemJeux">
# <a class="go-line" href="https://jeux.larousse.fr">
# <div class="icon"></div>
# <div class="name">JEUX</div>
# <div class="arrow"></div>
# </a>
# <hr/>
# </div>
# </div>
# </div>
# <!-- pub Native -->
# <!-- HOMEBOX TRADUCTION -->
# <!--
#
# <div>
#
#
#
#     <div class="traduction-zone-selector">
#         <div class="banner-title">
#             <p class="homebox-title">VOIR LA TRADUCTION</p>
#             <hr />
#         </div>
#         <div id="cphContent_LarousseRWDMaster_cphContent_DictionnairesMasterPage_HB_Traduction_FR_TRAD" class="traduction-lang-selector">
#             <div class="vl"></div>
#             <div class="">
#                 <div id="cphContent_LarousseRWDMaster_cphContent_DictionnairesMasterPage_HB_Traduction_TRAD_FR_EN" class="traduction-lang-item l-lang">
#                     <a href="/dictionnaires/francais-anglais/pis">
#                         <div class="waves-light"><img src="/dictionnaires/assets/img/flag-en.png" /></div>
#                         <p>Anglais</p>
#                     </a>
#                 </div>
#                 <div id="cphContent_LarousseRWDMaster_cphContent_DictionnairesMasterPage_HB_Traduction_TRAD_FR_IT" class="traduction-lang-item r-lang">
#                     <a href="/dictionnaires/francais-italien/pis">
#                         <div class="waves-light"><img src="/dictionnaires/assets/img/flag-it.png" /></div>
#                         <p>Italien</p>
#                     </a>
#                 </div>
#             </div>
#             <div class="">
#                 <div id="cphContent_LarousseRWDMaster_cphContent_DictionnairesMasterPage_HB_Traduction_TRAD_FR_DE" class="traduction-lang-item l-lang">
#                     <a href="/dictionnaires/francais-allemand/pis">
#                         <div class="waves-light"><img src="/dictionnaires/assets/img/flag-de.png" /></div>
#                         <p>Allemand</p>
#                     </a>
#                 </div>
#                 <div id="cphContent_LarousseRWDMaster_cphContent_DictionnairesMasterPage_HB_Traduction_TRAD_FR_ES" class="traduction-lang-item r-lang">
#                     <a href="/dictionnaires/francais-espagnol/pis">
#                         <div class="waves-light"><img src="/dictionnaires/assets/img/flag-es.png" /></div>
#                         <p>Espagnol</p>
#                     </a>
#                 </div>
#             </div>
#             <div class="">
#                 <div id="cphContent_LarousseRWDMaster_cphContent_DictionnairesMasterPage_HB_Traduction_TRAD_FR_CN" class="traduction-lang-item l-lang">
#                     <a href="/dictionnaires/francais-chinois/pis">
#                         <div class="waves-light"><img src="/dictionnaires/assets/img/flag-cn.png" /></div>
#                         <p>Chinois</p>
#                     </a>
#                 </div>
#                 <div id="cphContent_LarousseRWDMaster_cphContent_DictionnairesMasterPage_HB_Traduction_TRAD_FR_AR" class="traduction-lang-item r-lang">
#                     <a href="/dictionnaires/francais-arabe/pis">
#                         <div class="waves-light"><img src="/dictionnaires/assets/img/flag-ar.png" /></div>
#                         <p>Arabe</p>
#                     </a>
#                 </div>
#            </div>
#         </div>
#
#
#
#
#
#
#
#
#     </div>
#
# </div> -->
# <div class="pub-pave oasm2">
# </div>
# <!-- HOMEBOX QUIZZ -->
# <div class="hb-right-quizz">
# <div class="banner-title">
# <hr class="line-left"/>
# <span class="homebox-title">QUIZ</span>
# <hr class="line-right"/>
# </div>
# <!-- CSS (no-include MasterPage) -->
# <link href="/library-web/larcom/quizz/css/style-quizz.css" media="screen" rel="stylesheet" type="text/css"/>
# <div class="zone-quizz">
# <article id="Layout" onload="activeItem_qcu();">
# <section class="article-quizz">
# <div class="groupe-consigne-quizz">
# <p class="consigne-quizz">« Les équipes [grecque] et [turque] se sont affrontées. » Où faut-il mettre un « s » ?</p>
# </div>
# <ul class="liste-choix-unique">
# <li class="item-choix-unique">
# <ul class="liste-options" data-reponse="3" id="question1">
# <li class="item-options">
# <input class="radiobutton" id="question-5182" name="question1" type="radio" value="1"/>
# <label class="radiobutton-label" for="question-5182">à « grecque » mais pas à « turque »</label>
# </li>
# <li class="item-options">
# <input class="radiobutton" id="question-5183" name="question1" type="radio" value="2"/>
# <label class="radiobutton-label" for="question-5183">aux deux adjectifs</label>
# </li>
# <li class="item-options">
# <input class="radiobutton" id="question-5184" name="question1" type="radio" value="3"/>
# <label class="radiobutton-label" for="question-5184">à aucun des deux adjectifs</label>
# </li>
# </ul></li>
# </ul>
# </section>
# </article>
# <div>
# <section class="boutons-interactivite" id="QCU"></section>
# </div>
# </div>
# <!-- JS (no-include MasterPage) -->
# <script src="/library-web/larcom/quizz/js/libs/exercise-manager_bootstrap.js"></script>
# <script src="/library-web/larcom/quizz/js/typos/qcu-manager.js"></script>
# </div>
# <div class="BeOpinionWidget"></div>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="col-md-4">
# <!-- RIEN -->
# </div>
# </div>
# <!-- FIXED MENU NAV (FLOATING) -->
# <div class="navbox-fixed" id="cphContent_LarousseRWDMaster_cphContent_DictionnairesMasterPage_floatNav">
# <ul class="nav-menu">
# <li><a href="#definition">DÉFINITIONS</a></li><li><a href="#homonyme">HOMONYMES</a></li>
# </ul>
# <div class="nav-btn nav-open" onclick="openNavMenu();">+</div>
# <div class="nav-btn nav-close" onclick="closeNavMenu();"></div>
# </div>
# </div>
# <!-- JS (slick) !!! pb link jquery masterpage !!!-->
# <!-- <script type="text/javascript" src="./../assets/library/slick/slick.js"></script> -->
# <!-- JS (soundmanager2) -->
# <!-- <script type="text/javascript" src="/library-web/larcom/sound/soundmanager2-nodebug.js"></script> --> <!-- soundmanager2 -->
# <!-- JS (dictionnaires) !!! pb link jquery masterpage !!!-->
# <script src="/dictionnaires/assets/js/dictionnaires.202004101244.js" type="text/javascript"></script> <!-- src="../assets/js/dictionnaires.js" -->
# <!-- BANIERE(730 x 90) PUB BOTTOM -->
# <div class="pub-bottom oasb">
# </div>
# <!-- ## SOCIAL PANEL ## -->
# <!-- ################## -->
# <!-- ####### FOOTER ####### -->
# <div class="footer">
# <span class="footer-left">
# <a href="/index">Index</a>
# <a href="/infos/credits">Mentions légales et crédits</a>
# <a href="/infos/cgu">CGU</a>
# <a href="/infos/confidentialite">Charte de confidentialité</a>
# <a class="optanon-show-settings">Cookies</a>
# <a href="/infos/contact">Nous contacter</a>
# </span>
# <span class="footer-right">
# <span>© Larousse</span>
# </span>
# </div>
# <!-- ####### FOOTER ####### -->
# </div>
# </div></body>
# <!-- JS Bootstrap core JavaScript-->
# <script src="/library-web/bootstrap/js/bootstrap.min.js" type="text/javascript"></script> <!-- src="/library-web/bootstrap/js/bootstrap.js" -->
# <!-- JS MDB core JavaScript -->
# <script src="/library-web/mdb/js/mdb.min.js" type="text/javascript"></script> <!-- src="/library-web/mdb/js/mdb.js" -->
# <!-- JS SLICK core JavaScript -->
# <script src="/library-web/slick/slick.min.js" type="text/javascript"></script> <!-- src="/library-web/slick/slick.js" -->
# <script type="text/javascript">
#     var LAR_config = { "SAS_data": {"sitepage" : "www.larousse.fr/dictionnaire-de-francais", "siteid" : "3598", "type_top" : "1", "type_mid" : "2", "type_mid2" : "19", "type_outbrain" : "16", "type_bot" : "28", "type_body" : "5"}, "ga": "UA-8359745-2"};
# </script>
# <script type="text/javascript">
#     function OptanonWrapper() {
#         //alert("OptanonWrapper()");
#         window.dataLayer.push({event:'OneTrustGroupsUpdated'});     //TAGS Events
#     }
# </script>
# <!-- Fin de notification de consentement aux cookies de OneTrust -->
# <!-- JS-link larousse-CNIL (régisPub, GA, réseauxSociaux, ...) -->
# <!-- --------------------------------------------------------- -->
# <script src="/library-web/larcom/cnil/htmlParser.js"></script>
# <script src="/library-web/larcom/cnil/postscribe.js"></script>
# <script src="/library-web/larcom/cnil/ot-cnil.js"></script>
# <!-- RegisPUB & [OneTrust] (Params, Habillage(body,oast,oasm,...)) -->
# <!-- ------------------------------------------------------------- -->
# <!-- [OneTrust] CATEGORY-1: Cookies strictement nécessaires -->
# <script class="optanon-category-1" type="text/plain">
#         //alert("CATEGORY-1: OK \nCookies strictement nécessaires");
# </script>
# <!-- [OneTrust] CATEGORY-2: Cookies de performance -->
# <script class="optanon-category-2" type="text/plain">
#         //alert("CATEGORY-2: OK \nCookies de performance ");
#         //googleAnalytics();
#         //alert("googleAnalytics(): OK");
# </script>
# <!-- [OneTrust] CATEGORY-3: Cookies de fonctionnalité -->
# <script class="optanon-category-3" type="text/plain">
#         //alert("CATEGORY-3: OK \nCookies de fonctionnalité");
# </script>
# <!-- [OneTrust] CATEGORY-4: Cookies pour une publicité ciblée -->
# <script class="optanon-category-4" type="text/plain">
#         //alert("CATEGORY-4: OK \nCookies pour une publicité ciblée");
#         //initSAStrigger();   // regispub: trigger Pub (body, etc...) via smartadserver
#         //ads();              // regispub: themoneytizer
#         //AdsEx();            // regispub: quantx(elasticad), Teads
#         //alert("ads()-quantxAds(): OK");
# </script>
# <!-- [OneTrust] CATEGORY-8: Cookies « réseaux sociaux » -->
# <script class="optanon-category-8" type="text/plain">
#         //alert("CATEGORY-8: OK \nCookies réseaux sociaux");
#         //twitter();      // Box Twitter
#         //facebook();     // Box facebook
#         //googleplus();   // Box Google Plus
#         //alert("twitter()-facebook()-googleplus(): OK");
# </script>
# <!-- ########## FIN CNIL(RGPD) ##########  -->
# <!-- JS larousse-Masterpage -->
# <script src="/library-web/larcom/masterpage/js/masterpage.js" type="text/javascript"></script> <!-- src="[module]/assets/js/masterpage.js" -->
# </html>
