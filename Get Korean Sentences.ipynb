# %%
from wilcoxon.spiderman import *
from wilcoxon.language import *
import selenium

# %%
site = website("https://en.dict.naver.com/#/search?range=example&query=%ED%83%81%EC%9E%90")

# %%
site.html
# Out:
# <!DOCTYPE html>
# ...
