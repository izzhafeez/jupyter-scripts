# %%
from wilcoxon.spiderman import *
import re

# %%
api = "SyCVI2R0B_jywlOzJUxxpa2wCwno4KRpMj8"

# %%
site = website("https://www.youtube.com/c/IzzHafeez/videos")

# %%
site.html
# Out:
# <!DOCTYPE html>
# <html lang="en-GB" style="font-size: 10px;font-family: Roboto, Arial, sans-serif;"><head><meta content="IE=edge" http-equiv="X-UA-Compatible"/><script nonce="xQgvtSShHcnHgPYJWlb0eA">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else for(var k in a[0])ytcfg.d()[k]=a[0][k]}};
# window.ytcfg.set('EMERGENCY_BASE_URL', '\/error_204?t\x3djserror\x26level\x3dERROR\x26client.name\x3d1\x26client.version\x3d2.20210303.01.00');</script><script nonce="xQgvtSShHcnHgPYJWlb0eA">(function(){window.yterr=window.yterr||true;window.unhandledErrorMessages={};window.unhandledErrorCount=0;
# ...

# %%
site.html(string = re.compile("Lovesick"))
# Out:
# ['var ytInitialData = {"responseContext":{"serviceTrackingParams":[{"service":"GFEEDBACK","params":[{"key":"browse_id","value":"UCbpuVmLLEmLWDlCim2dCgoA"},{"key":"logged_in","value":"0"},{"key":"e","value":"24001541,23946420,24010073,24008642,23744176,24002714,23994474,23918597,24007246,23974883,24008863,23992808,23974595,24007901,23891344,23804281,23987676,24005206,23968386,24006795,24001373,23991263,23857949,23980552,24006265,24010254,24005870,23890959,24003347,23983500,23996624,23944779,23983296,23744530,23986021,23934970,23970529,23966208,24007400,1714246,24008766,23891346,23969934,23996751,23882502,23884386"}]},{"service":"GOOGLE_HELP","params":[{"key":"browse_id","value":"UCbpuVmLLEmLWDlCim2dCgoA"}]},{"service":"CSI","params":[{"key":"c","value":"WEB"},{"key":"cver","value":"2.20210303.01.00"},{"key":"yt_li","value":"0"},{"key":"GetChannelPage_rid","value":"0x67c7c600fc92cd98"}]},{"service":"GUIDED_HELP","params":[{"key":"logged_in","value":"0"}]},{"service":"ECATCHER","params"
# ...
